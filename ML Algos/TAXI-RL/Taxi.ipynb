# %%
import gym # type: ignore
import numpy as np # type: ignore
import random # type: ignore

# %%
env = gym.make('Taxi-v3')

ALPHA = 0.9 # learning rate
GAMMA = 0.95 # FUTURES REWARD DISCOUNT
EPSILON=1.0 # THE  CHANCE OF  GETTING  THE  BEST REWARD FOR  THE  NEXT ACTION
EPSILON_DECAY = 0.995
MIN_EPSILON = 0.01
EPISODES = 10000
MAX_STEP = 100 # MAXIMUM NUMBER OF STEPS IN A GAME

STATES = env.observation_space.n
ACTIONS = env.action_space.n
q_table = np.zeros((STATES, ACTIONS ))

# %%
def choose_action(state):
    if random.uniform(0, 1) < EPSILON:
        return env.action_space.sample()
    else:
        return np.argmax(q_table[state, :])


# Training the agent
for episode in range(EPISODES):
    print("Train EPISODE: ", episode)
    
    state = env.reset()[0]  
    done = False
    
    for step in range(MAX_STEP):
        action = choose_action(state)
        next_state, reward, done,_, info = env.step(action)
        
        q_table[state, action] = (1 - ALPHA) * q_table[state, action] + ALPHA * (
            reward + GAMMA * np.max(q_table[next_state, :]) 
        )
        
        state = next_state
        
        if done:
            break
    
    EPSILON = max(MIN_EPSILON, EPSILON * EPSILON_DECAY)
# Out:
# Train EPISODE:  0
# Train EPISODE:  1
# Train EPISODE:  2
# Train EPISODE:  3
# Train EPISODE:  4
# Train EPISODE:  5
# Train EPISODE:  6
# Train EPISODE:  7
# Train EPISODE:  8
# Train EPISODE:  9
# Train EPISODE:  10
# Train EPISODE:  11
# Train EPISODE:  12
# Train EPISODE:  13
# Train EPISODE:  14
# Train EPISODE:  15
# Train EPISODE:  16
# Train EPISODE:  17
# Train EPISODE:  18
# Train EPISODE:  19
# Train EPISODE:  20
# Train EPISODE:  21
# Train EPISODE:  22
# Train EPISODE:  23
# Train EPISODE:  24
# Train EPISODE:  25
# Train EPISODE:  26
# Train EPISODE:  27
# Train EPISODE:  28
# Train EPISODE:  29
# Train EPISODE:  30
# Train EPISODE:  31
# Train EPISODE:  32
# Train EPISODE:  33
# Train EPISODE:  34
# Train EPISODE:  35
# Train EPISODE:  36
# Train EPISODE:  37
# Train EPISODE:  38
# Train EPISODE:  39
# Train EPISODE:  40
# Train EPISODE:  41
# Train EPISODE:  42
# Train EPISODE:  43
# Train EPISODE:  44
# Train EPISODE:  45
# Train EPISODE:  46
# Train EPISODE:  47
# ...

# %%
env = gym.make('Taxi-v3', render_mode='human')

for episode in range(5):
    state = env.reset()[0]  
    done = False
    print("EPISODE: ", episode)
    
    for step in range(MAX_STEP):
        print(f"Step {step+1}, Current state: {state}")
        
        env.render()
        action = np.argmax(q_table[state, :])
        next_state, reward, done,_, info = env.step(action)
        state = next_state
        
        if done:
            env.render()
            print(f"Finished after {step+1} steps with reward {reward}")
            break

env.close()
# Out:
# EPISODE:  0
# Step 1, Current state: 454
# c:\Python312\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Step 2, Current state: 354
# Step 3, Current state: 254
# Step 4, Current state: 274
# Step 5, Current state: 374
# Step 6, Current state: 474
# Step 7, Current state: 478
# Step 8, Current state: 378
# Step 9, Current state: 278
# Step 10, Current state: 258
# Step 11, Current state: 238
# Step 12, Current state: 218
# Step 13, Current state: 318
# Step 14, Current state: 418
# Finished after 14 steps with reward 20
# EPISODE:  1
# Step 1, Current state: 361
# Step 2, Current state: 261
# Step 3, Current state: 241
# Step 4, Current state: 221
# Step 5, Current state: 121
# Step 6, Current state: 101
# Step 7, Current state: 1
# Step 8, Current state: 17
# Step 9, Current state: 117
# Step 10, Current state: 137
# ...
